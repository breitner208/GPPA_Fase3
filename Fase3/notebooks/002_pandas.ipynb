# %% [markdown]
# # PANDAS SERIES & DATAFRAMES
#
# *   Modulos
# *   Crear una serie
# *   Crear un dataframe
# *   Carga de datos
# *   Resumen de los datos: dimensiones y estructuras
# *   Detección y tratamiento de valores ausentes
# *   Variables dummy
# *   Ordenar el dataframe
# *   filtrar por columna o fila
# *   Query con pandas
# * Joins

# %% [markdown]
# ## Modulos
# *modulos/paquetes/librerias*
#
# * Previo a usar un modulo se debe primero *descargar*, *instalar* y luego si se puede *importar*

# %% [markdown]
# Si se recibe un error de este tipo *ModuleNotFoundError: No module named 'NOMBRE_MODULO_DESEADO'* se puede solucionar de la siguiente forma :
#
#     * en CMD/TERMINAL usar el comando: pip install NOMBRE_MODULO_DESEADO
#     * en la rutina se incluye la instrucción: !pip install NOMBRE_MODULO_DESEADO
#     * especificar las librerias/modulos que se necesitan y la versión en un requirements.txt

# %%
import os # importar los modulos

# %%
import pandas as pd # traernos las funciones para importar y trabajar con tablas de datos
import numpy as np # traernos las funciones para trabajar con arreglos/matrices/vectores datos

# %% [markdown]
# ## Crear una serie

# %% [markdown]
# Estructura unidimensional

# %% [markdown]
# * creando una serie de pandas a partir de un diccionario

# %%
# crear un diccionario
s = {
    'Jairo': 1020159, 
    'Felipe': 1020486, 
    'Omar': 1020754
    } 

# crear una serie de pandas usando el diccionario
ds_000 = pd.Series(s) 

# ver serie de pandas
ds_000
# Out:
# Jairo     1020159
# Felipe    1020486
# Omar      1020754
# dtype: int64

# %% [markdown]
# * creando una serie de pandas a partir de listas

# %%
valores = [1020159, 1020486, 1020754] # creamos un listado con la serie de informacion
list_indx = ['Jairo', 'Felipe', 'Omar'] # creamos un listado con los indices o nombres de las filas

ds_000 = pd.Series(
    valores,
    index = list_indx
    )# usamos la funcion pd.series para obtener una serie de pandas
ds_000
# Out:
# Jairo     1020159
# Felipe    1020486
# Omar      1020754
# dtype: int64

# %% [markdown]
# * crear una serie de pandas con solo una lista de valores

# %%
s = ['Jairo', 'Felipe', 'Omar']
ds_000 = pd.Series(s) # crear una serie de pandas solo con una lista
ds_000 # ver serie de pandas
# Out:
# 0     Jairo
# 1    Felipe
# 2      Omar
# dtype: object

# %% [markdown]
# ## Crear un dataframe
#
#     * NOMBRE UNICO QUE IDENTIFIQUE CADA COLUMNA : no hay dos columnas con el mismo nombre
#     * FORMATO : una misma columna no puede mas de un tipo de dato (o solamente numerica o solamente texto, o solamente otro tipo)

# %%
# crear un diccionario
dm_000 = {
    'Job Title': ['Android Developer', 'Full Stack Web Developer', 'Full Stack Web Developer'],
    'Salary': [3456, 6789,12345]
    }

# construir un dataframe a partir de un diccionario (las llaves las va a utilizar para generar columnas)
df_000 = pd.DataFrame(data=dm_000)
df_000
# Out:
#                   Job Title  Salary
# 0         Android Developer    3456
# 1  Full Stack Web Developer    6789
# 2  Full Stack Web Developer   12345

# %%
# crear un dataframe desde una serie de pandas
s = [1020159, 1020486, 1020754,999999] # lista de informacion con el salario
list_indx = ['Jairo', 'Felipe', 'Omar','juan'] # lista con el trabajador
ds_000 = pd.Series(s,index = list_indx) # crear una serie de pandas con la lista de informacion y de indices


# crear un diccionario utilizando la serie de pandas generada anteriormente
dm_000 = {
    'Job Title': ['Android Developer', 'Full Stack Web Developer', 'Full Stack Web Developer','Unemployed'],
    'Salary': ds_000
    }

df_000 = pd.DataFrame(data=dm_000) # crear el datfarame a partir de la serie de pandas
df_000
# Out:
#                        Job Title   Salary
# Jairo          Android Developer  1020159
# Felipe  Full Stack Web Developer  1020486
# Omar    Full Stack Web Developer  1020754
# juan                  Unemployed   999999

# %%
# crear una matriz o arreglo de datos usando numpy
da_000 = np.array(
    [
        ['Jairo', 'Android Developer', 1020159],
        ['Felipe', 'Full Stack Web Developer', 1020486],
        ['Omar', 'Full Stack Web Developer', 1020754]
        ]
        )

# a partir de un array de numpy construyo el dataframe
df_000 = pd.DataFrame(
    data= da_000,
    columns= ['Name', 'Job Title', 'Salary']
    ) # usar el arrglo de numpy e indicar explicitamente el nopmbre las columnas

df_000
# Out:
#      Name                 Job Title   Salary
# 0   Jairo         Android Developer  1020159
# 1  Felipe  Full Stack Web Developer  1020486
# 2    Omar  Full Stack Web Developer  1020754

# %% [markdown]
# * generar un dataframe vacío

# %%
df_000 = pd.DataFrame()
df_000
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Carga de datos

# %% [markdown]
# **Qué se necesita para leer/acceder a un recurso de información? ...**
#
# 1. Saber dónde está ubicado?
# 2. Saber cómo se llama el recurso de información?
# 3. Qué método/estrategia/función me sirve para leerlo?

# %% [markdown]
# ### Carga de un archivo plano

# %%
# CONSTRUIR LA DIRECCION DE UBICACION UN RECURSO DE INFORMACION
mainpath = "https://raw.githubusercontent.com/UnadEdgarRuiz/Curso-Python/refs/heads/main/" # direccion o ruta de ubicacion del archivo
filename = "Salary_Dataset_with_Extra_Features.csv" # el nombre del archivo y la extension
fullpath = os.path.join(mainpath, filename) # concatenar la direccion completa
fullpath
# Out:
# 'https://raw.githubusercontent.com/UnadEdgarRuiz/Curso-Python/refs/heads/main/Salary_Dataset_with_Extra_Features.csv'

# %% [markdown]
#     * pd.read_csv()

# %%
 # utilizar la funcion de lectura de "archivos planos" de pandas para leer archivo ubicado en la ruta
df_000 = pd.read_csv(fullpath) # lea archivo en ruta ( .txt , .csv y .tsv)
df_000 # muestreme que hay en la variable
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# 0       400000                  3  Bangalore         Full Time   Android
# 1       400000                  3  Bangalore         Full Time   Android
# 2      1000000                  3  Bangalore         Full Time   Android
# 3       300000                  3  Bangalore         Full Time   Android
# 4       600000                  3  Bangalore         Full Time   Android
# ...        ...                ...        ...               ...       ...
# 22765   200000                  1  Bangalore         Full Time       Web
# 22766   300000                  1  Bangalore         Full Time       Web
# 22767   192000                 13  Bangalore         Full Time       Web
# 22768   300000                  7  Bangalore         Full Time       Web
# 22769   300000                  7  Bangalore         Full Time       Web
#
# [22770 rows x 8 columns]

# %% [markdown]
# * parametrizar la lectura del archivo

# %%
df_001 = pd.read_csv(fullpath, sep=",") # seperador de columnas
df_001
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# 0       400000                  3  Bangalore         Full Time   Android
# 1       400000                  3  Bangalore         Full Time   Android
# 2      1000000                  3  Bangalore         Full Time   Android
# 3       300000                  3  Bangalore         Full Time   Android
# 4       600000                  3  Bangalore         Full Time   Android
# ...        ...                ...        ...               ...       ...
# 22765   200000                  1  Bangalore         Full Time       Web
# 22766   300000                  1  Bangalore         Full Time       Web
# 22767   192000                 13  Bangalore         Full Time       Web
# 22768   300000                  7  Bangalore         Full Time       Web
# 22769   300000                  7  Bangalore         Full Time       Web
#
# [22770 rows x 8 columns]

# %%
df_001 = pd.read_csv(
    fullpath, # ruta
    sep=",", # separador
    header = 'infer' # lectura del encabezado
    ) # parametrizar la lectura del archivo
df_001
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# 0       400000                  3  Bangalore         Full Time   Android
# 1       400000                  3  Bangalore         Full Time   Android
# 2      1000000                  3  Bangalore         Full Time   Android
# 3       300000                  3  Bangalore         Full Time   Android
# 4       600000                  3  Bangalore         Full Time   Android
# ...        ...                ...        ...               ...       ...
# 22765   200000                  1  Bangalore         Full Time       Web
# 22766   300000                  1  Bangalore         Full Time       Web
# 22767   192000                 13  Bangalore         Full Time       Web
# 22768   300000                  7  Bangalore         Full Time       Web
# 22769   300000                  7  Bangalore         Full Time       Web
#
# [22770 rows x 8 columns]

# %%
list_colnames = ['A', 'B', 'C', 'D', 'E', 'F', 'G','H'] # creo un listado ( de nombres de columnas)

df_002 = pd.read_csv(
    fullpath, # ruta
    sep=",", # separador
    names = list_colnames # el listado de nombres de columnas
    ) # leer el archivo indicando el nombre de las columnas

df_002
# Out:
#             A                                 B                         C  \
# 0      Rating                      Company Name                 Job Title
# 1         3.8                            Sasken         Android Developer
# 2         4.5  Advanced Millennium Technologies         Android Developer
# 3         4.0                         Unacademy         Android Developer
# 4         3.8                SnapBizz Cloudtech         Android Developer
# ...       ...                               ...                       ...
# 22766     4.7                  Expert Solutions             Web Developer
# 22767     4.0           Nextgen Innovation Labs             Web Developer
# 22768     4.1                           Fresher  Full Stack Web Developer
# 22769     4.1                         Accenture  Full Stack Web Developer
# 22770     3.8                   Thomson Reuters   Associate Web Developer
#
#              D                  E          F                  G          H
# 0       Salary  Salaries Reported   Location  Employment Status  Job Roles
# 1       400000                  3  Bangalore          Full Time    Android
# 2       400000                  3  Bangalore          Full Time    Android
# 3      1000000                  3  Bangalore          Full Time    Android
# 4       300000                  3  Bangalore          Full Time    Android
# ...        ...                ...        ...                ...        ...
# 22766   200000                  1  Bangalore          Full Time        Web
# 22767   300000                  1  Bangalore          Full Time        Web
# 22768   192000                 13  Bangalore          Full Time        Web
# 22769   300000                  7  Bangalore          Full Time        Web
# 22770   300000                  7  Bangalore          Full Time        Web
#
# [22771 rows x 8 columns]

# %%
list_colnames = ['A', 'B', 'C', 'D', 'E', 'F', 'G','H'] # creo un listado ( de nombres de columnas)

df_003 = pd.read_csv(
    fullpath,
    sep=",",
    names = list_colnames,

    skiprows = 1 # salte la la primer fila en la lectura
    )
df_003
# Out:
#          A                                 B                         C  \
# 0      3.8                            Sasken         Android Developer
# 1      4.5  Advanced Millennium Technologies         Android Developer
# 2      4.0                         Unacademy         Android Developer
# 3      3.8                SnapBizz Cloudtech         Android Developer
# 4      4.4            Appoids Tech Solutions         Android Developer
# ...    ...                               ...                       ...
# 22765  4.7                  Expert Solutions             Web Developer
# 22766  4.0           Nextgen Innovation Labs             Web Developer
# 22767  4.1                           Fresher  Full Stack Web Developer
# 22768  4.1                         Accenture  Full Stack Web Developer
# 22769  3.8                   Thomson Reuters   Associate Web Developer
#
#              D   E          F          G        H
# 0       400000   3  Bangalore  Full Time  Android
# 1       400000   3  Bangalore  Full Time  Android
# 2      1000000   3  Bangalore  Full Time  Android
# 3       300000   3  Bangalore  Full Time  Android
# 4       600000   3  Bangalore  Full Time  Android
# ...        ...  ..        ...        ...      ...
# 22765   200000   1  Bangalore  Full Time      Web
# 22766   300000   1  Bangalore  Full Time      Web
# 22767   192000  13  Bangalore  Full Time      Web
# 22768   300000   7  Bangalore  Full Time      Web
# 22769   300000   7  Bangalore  Full Time      Web
#
# [22770 rows x 8 columns]

# %% [markdown]
# ### Carga de un archivo de excel

# %%
# construir ruta de ubicacion del archivo
mainpath = "https://raw.githubusercontent.com/UnadEdgarRuiz/Curso-Python/refs/heads/main/"
filename = "Salary_Dataset_with_Extra_Features.xlsx"
fullpath = os.path.join(mainpath, filename)
fullpath
# Out:
# 'https://raw.githubusercontent.com/UnadEdgarRuiz/Curso-Python/refs/heads/main/Salary_Dataset_with_Extra_Features.xlsx'

# %% [markdown]
#     * pd.read_excel

# %% [markdown]
# *NOTA* :  se debe tener instaldo el modulo --openpyxl--

# %%
df_004 = pd.read_excel(fullpath) # usar la funcion de lectura de excel para pandas
df_004
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# 0       400000                  3  Bangalore         Full Time   Android
# 1       400000                  3  Bangalore         Full Time   Android
# 2      1000000                  3  Bangalore         Full Time   Android
# 3       300000                  3  Bangalore         Full Time   Android
# 4       600000                  3  Bangalore         Full Time   Android
# ...        ...                ...        ...               ...       ...
# 22765   200000                  1  Bangalore         Full Time       Web
# 22766   300000                  1  Bangalore         Full Time       Web
# 22767   192000                 13  Bangalore         Full Time       Web
# 22768   300000                  7  Bangalore         Full Time       Web
# 22769   300000                  7  Bangalore         Full Time       Web
#
# [22770 rows x 8 columns]

# %%
# para una descripcion rapida del dataframe
df_004.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22769 non-null  object
#  2   Job Title          22770 non-null  object
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  object
#  6   Employment Status  22770 non-null  object
#  7   Job Roles          22770 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
df_004 = pd.read_excel(
    fullpath,
    sheet_name = 0 # seleccionar una hojas del excel
    ) # usar la funcion de lectura de excel para pandas
df_004
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# 0       400000                  3  Bangalore         Full Time   Android
# 1       400000                  3  Bangalore         Full Time   Android
# 2      1000000                  3  Bangalore         Full Time   Android
# 3       300000                  3  Bangalore         Full Time   Android
# 4       600000                  3  Bangalore         Full Time   Android
# ...        ...                ...        ...               ...       ...
# 22765   200000                  1  Bangalore         Full Time       Web
# 22766   300000                  1  Bangalore         Full Time       Web
# 22767   192000                 13  Bangalore         Full Time       Web
# 22768   300000                  7  Bangalore         Full Time       Web
# 22769   300000                  7  Bangalore         Full Time       Web
#
# [22770 rows x 8 columns]

# %%
df_004 = pd.read_excel(
    fullpath,
    sheet_name = 'Hoja1' # seleccionar una hojas del excel
    ) # usar la funcion de lectura de excel para pandas
df_004
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# 0       400000                  3  Bangalore         Full Time   Android
# 1       400000                  3  Bangalore         Full Time   Android
# 2      1000000                  3  Bangalore         Full Time   Android
# 3       300000                  3  Bangalore         Full Time   Android
# 4       600000                  3  Bangalore         Full Time   Android
# ...        ...                ...        ...               ...       ...
# 22765   200000                  1  Bangalore         Full Time       Web
# 22766   300000                  1  Bangalore         Full Time       Web
# 22767   192000                 13  Bangalore         Full Time       Web
# 22768   300000                  7  Bangalore         Full Time       Web
# 22769   300000                  7  Bangalore         Full Time       Web
#
# [22770 rows x 8 columns]

# %% [markdown]
# ## Carga masiva de archivos

# %%
# lista de adirecciones donde estan ubicados cada uno de los archivo
list_filename = [
    "https://raw.githubusercontent.com/UnadEdgarRuiz/Curso-Python/refs/heads/main/Salary_Dataset_with_Extra_Features_pt1.xlsx",
    "https://raw.githubusercontent.com/UnadEdgarRuiz/Curso-Python/refs/heads/main/Salary_Dataset_with_Extra_Features_pt2.xlsx",
    "https://raw.githubusercontent.com/UnadEdgarRuiz/Curso-Python/refs/heads/main/Salary_Dataset_with_Extra_Features_pt3.xlsx"
    ]

# crear una lista vacia contenedora
list_df = [] 

#estructura de control for
for file_i in list_filename:
  list_df.append(pd.read_excel(file_i)) # la lista vacia se va a llenar de cada uno de los dataframes que va a leer

list_df # ver contenido de la lista
# Out:
# [      Rating                      Company Name          Job Title   Salary  \
#  0        3.8                            Sasken  Android Developer   400000
#  1        4.5  Advanced Millennium Technologies  Android Developer   400000
#  2        4.0                         Unacademy  Android Developer  1000000
#  3        3.8                SnapBizz Cloudtech  Android Developer   300000
#  4        4.4            Appoids Tech Solutions  Android Developer   600000
#  ...      ...                               ...                ...      ...
#  3408     4.0                  Fresherworld.com    Backend Process   180000
#  3409     3.8                       NCC Limited    Backend Process   300000
#  3410     4.5                             Groww    Backend Process   120000
#  3411     4.0                              Vogo    Backend Process   216000
#  3412     3.6                              FHPL    Backend Process   200000
#
#        Salaries Reported   Location Employment Status Job Roles
#  0                     3  Bangalore         Full Time   Android
#  1                     3  Bangalore         Full Time   Android
#  2                     3  Bangalore         Full Time   Android
#  3                     3  Bangalore         Full Time   Android
#  4                     3  Bangalore         Full Time   Android
#  ...                 ...        ...               ...       ...
#  3408                  1  Bangalore         Full Time   Backend
#  3409                  1  Bangalore         Full Time   Backend
#  3410                  1  Bangalore         Full Time   Backend
#  3411                  1  Bangalore         Full Time   Backend
#  3412                  1  Bangalore         Full Time   Backend
#
#  [3413 rows x 8 columns],
#         Rating                    Company Name  \
#  0         3.8                             LTI
#  1         5.0                         MyDBOPS
#  2         3.8           Yellow Umbrella Group
#  3         3.5                      ArisGlobal
#  4         3.8     Laneâ€™s Landscape Supplies
#  ...       ...                             ...
#  10025     3.9       Tata Consultancy Services
#  10026     3.3                         Infosys
#  10027     3.8  Cognizant Technology Solutions
#  10028     3.8  Cognizant Technology Solutions
#  10029     3.7                HCL Technologies
#
#                                            Job Title   Salary  \
#  0                            Database Administrator  2000000
#  1                            Database Administrator   400000
#  2                            Database Administrator  1300000
#  3                            Database Administrator  1200000
#  4                            Database Administrator   100000
#  ...                                             ...      ...
#  10025  Software Development Engineer In Test (SDET)   600000
#  10026  Software Development Engineer In Test (SDET)   828000
#  10027  Software Development Engineer In Test (SDET)   444000
#  10028  Software Development Engineer In Test (SDET)   876000
#  10029  Software Development Engineer In Test (SDET)   500000
#
#         Salaries Reported   Location Employment Status Job Roles
#  0                      1  Bangalore         Full Time  Database
#  1                      1  Bangalore         Full Time  Database
#  2                      1  Bangalore         Full Time  Database
#  3                      1  Bangalore         Full Time  Database
#  4                      1  Bangalore         Full Time  Database
#  ...                  ...        ...               ...       ...
#  10025                  1    Chennai         Full Time       SDE
#  10026                  1    Chennai         Full Time       SDE
#  10027                  1    Chennai         Full Time       SDE
#  10028                  1    Chennai         Full Time       SDE
#  10029                  1    Chennai         Full Time       SDE
#
#  [10030 rows x 8 columns],
#        Rating             Company Name  \
#  0        3.7                      Jio
#  1        4.1                  Dream11
#  2        3.0                     Lido
#  3        4.2                Media.net
#  4        4.1            First Student
#  ...      ...                      ...
#  6241     4.7         Expert Solutions
#  6242     4.0  Nextgen Innovation Labs
#  6243     4.1                  Fresher
#  6244     4.1                Accenture
#  6245     3.8          Thomson Reuters
#
#                                             Job Title   Salary  \
#  0       Software Development Engineer In Test (SDET)   400000
#  1     Software Development Engineer In Test (SDET) I   900000
#  2                    Software Development Engineer I  1000000
#  3                   Software Development Engineer II  2600000
#  4                Software Development Engineer (SDE)   300000
#  ...                                              ...      ...
#  6241                                   Web Developer   200000
#  6242                                   Web Developer   300000
#  6243                        Full Stack Web Developer   192000
#  6244                        Full Stack Web Developer   300000
#  6245                         Associate Web Developer   300000
#
#        Salaries Reported   Location Employment Status Job Roles
#  0                     4     Mumbai         Full Time       SDE
#  1                     4     Mumbai         Full Time       SDE
#  2                     3     Mumbai         Full Time       SDE
#  3                     3     Mumbai         Full Time       SDE
#  4                     3     Mumbai         Full Time       SDE
#  ...                 ...        ...               ...       ...
#  6241                  1  Bangalore         Full Time       Web
#  6242                  1  Bangalore         Full Time       Web
#  6243                 13  Bangalore         Full Time       Web
#  6244                  7  Bangalore         Full Time       Web
#  6245                  7  Bangalore         Full Time       Web
#
#  [6246 rows x 8 columns]]

# %% [markdown]
# ![picture](https://raw.githubusercontent.com/elprincipitogauss/lesson/main/bindrows.png)

# %%
# canaatidad de filas de cada dataframe
3413+10030+6246
# Out:
# 19689

# %% [markdown]
#     * pd.concat

# %%
# enlistamos las direcciones a consultar con los exceles
list_filename = [
    "https://raw.githubusercontent.com/UnadEdgarRuiz/Curso-Python/refs/heads/main/Salary_Dataset_with_Extra_Features_pt1.xlsx",
    "https://raw.githubusercontent.com/UnadEdgarRuiz/Curso-Python/refs/heads/main/Salary_Dataset_with_Extra_Features_pt2.xlsx",
    "https://raw.githubusercontent.com/UnadEdgarRuiz/Curso-Python/refs/heads/main/Salary_Dataset_with_Extra_Features_pt3.xlsx"
    ]

# nota : no se necesita generar dataframe contenedor vacio

# recorrer la lista para leer cada uno de los exceles
for file_i in list_filename:

  df_a = pd.read_excel(file_i) # generar un dataframe leyendo la direccion en el iterando
  
  try: # intente realizar ...
    df_cont = pd.concat([df_cont,df_a]) # pegar por abajo la nueva base leida a la base inicial
  except:
    df_cont = df_a # el datframe leido va a ser el datframe inicial del contenedor

df_cont
# Out:
#       Rating                      Company Name                 Job Title  \
# 0        3.8                            Sasken         Android Developer
# 1        4.5  Advanced Millennium Technologies         Android Developer
# 2        4.0                         Unacademy         Android Developer
# 3        3.8                SnapBizz Cloudtech         Android Developer
# 4        4.4            Appoids Tech Solutions         Android Developer
# ...      ...                               ...                       ...
# 6241     4.7                  Expert Solutions             Web Developer
# 6242     4.0           Nextgen Innovation Labs             Web Developer
# 6243     4.1                           Fresher  Full Stack Web Developer
# 6244     4.1                         Accenture  Full Stack Web Developer
# 6245     3.8                   Thomson Reuters   Associate Web Developer
#
#        Salary  Salaries Reported   Location Employment Status Job Roles
# 0      400000                  3  Bangalore         Full Time   Android
# 1      400000                  3  Bangalore         Full Time   Android
# 2     1000000                  3  Bangalore         Full Time   Android
# 3      300000                  3  Bangalore         Full Time   Android
# 4      600000                  3  Bangalore         Full Time   Android
# ...       ...                ...        ...               ...       ...
# 6241   200000                  1  Bangalore         Full Time       Web
# 6242   300000                  1  Bangalore         Full Time       Web
# 6243   192000                 13  Bangalore         Full Time       Web
# 6244   300000                  7  Bangalore         Full Time       Web
# 6245   300000                  7  Bangalore         Full Time       Web
#
# [19689 rows x 8 columns]

# %% [markdown]
# * listar archivos de un directorio

# %%
def busqueda_directorio_archivos(directorio,patron):
    """
    directorio: es la ruta del directorio que se quiere explorar
    patron: el patron que debe coincidir con el nombre en la busqueda de los archivos
    """
    archivos = os.listdir(directorio)
    resultado = list(filter(lambda x: patron in x, archivos))
    return resultado

# %%
busqueda_directorio_archivos(directorio = '.',patron = 'Salary')
# Out:
# ['Salary_Dataset_with_Extra_Features.csv',
#  'Salary_Dataset_with_Extra_Features.csv.zip',
#  'Salary_Dataset_with_Extra_Features.xlsx',
#  'Salary_Dataset_with_Extra_Features_pt1.xlsx',
#  'Salary_Dataset_with_Extra_Features_pt2.xlsx',
#  'Salary_Dataset_with_Extra_Features_pt3.xlsx']

# %% [markdown]
# ## Resumen de los datos: dimensiones y estructuras

# %%
# backup de la información
df = df_000.copy() # reserva una copia de la informacion en la memoria
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# 0       400000                  3  Bangalore         Full Time   Android
# 1       400000                  3  Bangalore         Full Time   Android
# 2      1000000                  3  Bangalore         Full Time   Android
# 3       300000                  3  Bangalore         Full Time   Android
# 4       600000                  3  Bangalore         Full Time   Android
# ...        ...                ...        ...               ...       ...
# 22765   200000                  1  Bangalore         Full Time       Web
# 22766   300000                  1  Bangalore         Full Time       Web
# 22767   192000                 13  Bangalore         Full Time       Web
# 22768   300000                  7  Bangalore         Full Time       Web
# 22769   300000                  7  Bangalore         Full Time       Web
#
# [22770 rows x 8 columns]

# %%
df.head(5) #  encabezado del dataframe
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
df.tail(5) # la cola de la tabla
# Out:
#        Rating             Company Name                 Job Title  Salary  \
# 22765     4.7         Expert Solutions             Web Developer  200000
# 22766     4.0  Nextgen Innovation Labs             Web Developer  300000
# 22767     4.1                  Fresher  Full Stack Web Developer  192000
# 22768     4.1                Accenture  Full Stack Web Developer  300000
# 22769     3.8          Thomson Reuters   Associate Web Developer  300000
#
#        Salaries Reported   Location Employment Status Job Roles
# 22765                  1  Bangalore         Full Time       Web
# 22766                  1  Bangalore         Full Time       Web
# 22767                 13  Bangalore         Full Time       Web
# 22768                  7  Bangalore         Full Time       Web
# 22769                  7  Bangalore         Full Time       Web

# %%
df.columns # el nombre de las columnas de la tabla
# Out:
# Index(['Rating', 'Company Name', 'Job Title', 'Salary', 'Salaries Reported',
#        'Location', 'Employment Status', 'Job Roles'],
#       dtype='object')

# %%
df.shape # las dimensiones del dataframe (rows, columns)
# Out:
# (22770, 8)

# %%
# resumen estdistico de cada columna
# segun de el tipo de datos realizar un descriptivo rapido
# da prioridad a las columnas numericas
df.describe()
# Out:
#              Rating        Salary  Salaries Reported
# count  22769.000000  2.277000e+04       22770.000000
# mean       3.918209  6.953872e+05           1.855775
# std        0.519686  8.843990e+05           6.823668
# min        1.000000  2.112000e+03           1.000000
# 25%        3.700000  3.000000e+05           1.000000
# 50%        3.900000  5.000000e+05           1.000000
# 75%        4.200000  9.000000e+05           1.000000
# max        5.000000  9.000000e+07         361.000000

# %% [markdown]
# * Nota : seleccionar columnas de un dataframe usando las llavesdataframe
# [[columna_1, columna_2,..., columna_n]]

# %%
# resumen estdistico de cada columna
# segun de el tipo de datos realizar un descriptivo rapido
# da prioridad a las columnas numericas se debe filtrar solo texto eenn caso de describir cols texto
df[['Company Name', 'Job Title']].describe()
# Out:
#                      Company Name                      Job Title
# count                       22769                          22770
# unique                      11260                           1080
# top     Tata Consultancy Services  Software Development Engineer
# freq                          271                           2351

# %%
df.dtypes # tipo de datos en cada columna
# Out:
# Rating               float64
# Company Name          object
# Job Title             object
# Salary                 int64
# Salaries Reported      int64
# Location              object
# Employment Status     object
# Job Roles             object
# dtype: object

# %%
df.info() # resumen rapido de la informacion del dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22769 non-null  object
#  2   Job Title          22770 non-null  object
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  object
#  6   Employment Status  22770 non-null  object
#  7   Job Roles          22770 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Tratamiento y detección de valores ausentes

# %%
# variable que se le asigna un texto que es el nombre de una columna #feature=atributos=variables=columnas
ftr_name = "Rating"

# %%
# ver columna seleccionada
df[ftr_name]
# Out:
# 0        3.8
# 1        4.5
# 2        4.0
# 3        3.8
# 4        4.4
#         ...
# 22765    4.7
# 22766    4.0
# 22767    4.1
# 22768    4.1
# 22769    3.8
# Name: Rating, Length: 22770, dtype: float64

# %%
# si la informacion de cada elemento de la columna es nula
pd.isnull(df[ftr_name])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22765    False
# 22766    False
# 22767    False
# 22768    False
# 22769    False
# Name: Rating, Length: 22770, dtype: bool

# %%
# si la informacion de cada elemento de la columna no es nula
pd.notnull(df[ftr_name])
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 22765    True
# 22766    True
# 22767    True
# 22768    True
# 22769    True
# Name: Rating, Length: 22770, dtype: bool

# %%
# cuantos vacios hay?
cuantos_vacios = pd.isnull(df[ftr_name]).values.ravel().sum() # sumar los trues (cuando es vacio)
print('La columna '+ftr_name+ ' posee {} registros vacíos'.format(cuantos_vacios))
# Out:
# La columna Rating posee 0 registros vacíos

# %%
# cuantos no son vacios?
cuantos_llenos = pd.notnull(df[ftr_name]).values.ravel().sum() # suma los trues (cuando no es vacio)
print('La columna '+ftr_name+ ' posee {} registros con información'.format(cuantos_llenos))
# Out:
# La columna Rating posee 22770 registros con información

# %% [markdown]
# ### Borrar valores ausentes

# %%
# filtrar el dataframe según el registro que posee vacios en la columna
df[pd.isnull(df[ftr_name])]
# Out:
# Empty DataFrame
# Columns: [Rating, Company Name, Job Title, Salary, Salaries Reported, Location, Employment Status, Job Roles]
# Index: []

# %%
# recorrer el dataframe usando los numeros de filas
# otr form  de usar rangos usando : limite_inferior:limite_superior
# nnunca lleg al limite_superior
# iloc loclizr por index
df.iloc[16:21]
# Out:
#     Rating       Company Name          Job Title   Salary  Salaries Reported  \
# 16     3.6  Novopay Solutions  Android Developer   600000                  2
# 17     3.7       WealthEngine  Android Developer   360000                  2
# 18     4.0        J.P. Morgan  Android Developer  1000000                  2
# 19     3.6             Acviss  Android Developer   500000                  2
# 20     4.1            Fresher  Android Developer   408000                  2
#
#      Location Employment Status Job Roles
# 16  Bangalore         Full Time   Android
# 17  Bangalore         Full Time   Android
# 18  Bangalore         Full Time   Android
# 19  Bangalore         Full Time   Android
# 20  Bangalore         Full Time   Android

# %% [markdown]
# * revisión y borrado por eje filas

# %%
# borrar filas que contengan todos los campos vacios
df.dropna(
    axis=0,  # cuando axis = 0 hace referencia a las filas
    how="all" # todos los campos vacios
    ).iloc[16:21]
# Out:
#     Rating       Company Name          Job Title   Salary  Salaries Reported  \
# 16     3.6  Novopay Solutions  Android Developer   600000                  2
# 17     3.7       WealthEngine  Android Developer   360000                  2
# 18     4.0        J.P. Morgan  Android Developer  1000000                  2
# 19     3.6             Acviss  Android Developer   500000                  2
# 20     4.1            Fresher  Android Developer   408000                  2
#
#      Location Employment Status Job Roles
# 16  Bangalore         Full Time   Android
# 17  Bangalore         Full Time   Android
# 18  Bangalore         Full Time   Android
# 19  Bangalore         Full Time   Android
# 20  Bangalore         Full Time   Android

# %%
# borrar filas que contengan por lo menos un campo
df.dropna(
    axis=0, # cuando axis = 0 hace referencia a las filas
    how="any" # por lo menos algun campo esté vacio
    ).iloc[16:21]
# Out:
#     Rating       Company Name          Job Title   Salary  Salaries Reported  \
# 16     3.6  Novopay Solutions  Android Developer   600000                  2
# 17     3.7       WealthEngine  Android Developer   360000                  2
# 18     4.0        J.P. Morgan  Android Developer  1000000                  2
# 19     3.6             Acviss  Android Developer   500000                  2
# 20     4.1            Fresher  Android Developer   408000                  2
#
#      Location Employment Status Job Roles
# 16  Bangalore         Full Time   Android
# 17  Bangalore         Full Time   Android
# 18  Bangalore         Full Time   Android
# 19  Bangalore         Full Time   Android
# 20  Bangalore         Full Time   Android

# %% [markdown]
# * revisión y borrado por eje columnas

# %%
# borrar columnas que contengan todos los registros vacios
df.dropna(
    axis=1, # cuando axis = 1 el entiendo que va a realizarlo por columnas
    how="all"
    ).iloc[16:21]
# Out:
#     Rating       Company Name          Job Title   Salary  Salaries Reported  \
# 16     3.6  Novopay Solutions  Android Developer   600000                  2
# 17     3.7       WealthEngine  Android Developer   360000                  2
# 18     4.0        J.P. Morgan  Android Developer  1000000                  2
# 19     3.6             Acviss  Android Developer   500000                  2
# 20     4.1            Fresher  Android Developer   408000                  2
#
#      Location Employment Status Job Roles
# 16  Bangalore         Full Time   Android
# 17  Bangalore         Full Time   Android
# 18  Bangalore         Full Time   Android
# 19  Bangalore         Full Time   Android
# 20  Bangalore         Full Time   Android

# %%
# borrar columnas que contengan por lo menos un campo
df.dropna(
    axis=1, # cuando axis = 1 el entiendo que va a realizarlo por columnas
    how="any"
    ).iloc[16:21]
# Out:
#     Rating          Job Title   Salary  Salaries Reported   Location  \
# 16     3.6  Android Developer   600000                  2  Bangalore
# 17     3.7  Android Developer   360000                  2  Bangalore
# 18     4.0  Android Developer  1000000                  2  Bangalore
# 19     3.6  Android Developer   500000                  2  Bangalore
# 20     4.1  Android Developer   408000                  2  Bangalore
#
#    Employment Status Job Roles
# 16         Full Time   Android
# 17         Full Time   Android
# 18         Full Time   Android
# 19         Full Time   Android
# 20         Full Time   Android

# %% [markdown]
# ### imputar valores ausentes

# %%
df_imputed = df.copy() # copy realiza una copia en otra variable

# %%
df_imputed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22769 non-null  object
#  2   Job Title          22770 non-null  object
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  object
#  6   Employment Status  22770 non-null  object
#  7   Job Roles          22770 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
# llene todos los vacios (NaN NA Null) con "ceros" numerico
df_test_000 = df_imputed.fillna(0)
print(df_test_000.iloc[16:21] )
df_test_000.info()
# Out:
#     Rating       Company Name          Job Title   Salary  Salaries Reported  \
# 16     3.6  Novopay Solutions  Android Developer   600000                  2
# 17     3.7       WealthEngine  Android Developer   360000                  2
# 18     4.0        J.P. Morgan  Android Developer  1000000                  2
# 19     3.6             Acviss  Android Developer   500000                  2
# 20     4.1            Fresher  Android Developer   408000                  2
#
#      Location Employment Status Job Roles
# 16  Bangalore         Full Time   Android
# 17  Bangalore         Full Time   Android
# 18  Bangalore         Full Time   Android
# 19  Bangalore         Full Time   Android
# 20  Bangalore         Full Time   Android
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22770 non-null  object
#  2   Job Title          22770 non-null  object
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  object
#  6   Employment Status  22770 non-null  object
#  7   Job Roles          22770 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
df_test_000 = df_imputed.fillna('0')
print(df_test_000.iloc[16:21] )
df_test_000.info() # llene todos los vacios con "ceros" en texto
# Out:
#     Rating       Company Name          Job Title   Salary  Salaries Reported  \
# 16     3.6  Novopay Solutions  Android Developer   600000                  2
# 17     3.7       WealthEngine  Android Developer   360000                  2
# 18     4.0        J.P. Morgan  Android Developer  1000000                  2
# 19     3.6             Acviss  Android Developer   500000                  2
# 20     4.1            Fresher  Android Developer   408000                  2
#
#      Location Employment Status Job Roles
# 16  Bangalore         Full Time   Android
# 17  Bangalore         Full Time   Android
# 18  Bangalore         Full Time   Android
# 19  Bangalore         Full Time   Android
# 20  Bangalore         Full Time   Android
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22770 non-null  object
#  2   Job Title          22770 non-null  object
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  object
#  6   Employment Status  22770 non-null  object
#  7   Job Roles          22770 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
# #dos formas de guardar el resultado del cambio
# df_imputed.fillna('0',inplace=True)
# df_imputed = df_imputed.fillna('0')

# %% [markdown]
# * realizar la imputacion según el contexto

# %%
# seleccionar columna quie se quiere afectar (imputar)
ftr_name = 'Rating'

# saca el promedio de la columna seleccionada
promedio = df_imputed[ftr_name].mean() 
# saca el promedio de la columna seleccionada
mediana = df_imputed[ftr_name].median() 

print('el promedio de la columna {} es {} y su mediana es {}'.format(ftr_name,str(promedio),str(mediana)))
# Out:
# el promedio de la columna Rating es 3.9182125603864733 y su mediana es 3.9

# %%
# recorrer el dataframe usando los numeros de filas
df.iloc[16:21]
# Out:
#     Rating       Company Name          Job Title   Salary  Salaries Reported  \
# 16     3.6  Novopay Solutions  Android Developer   600000                  2
# 17     3.7       WealthEngine  Android Developer   360000                  2
# 18     4.0        J.P. Morgan  Android Developer  1000000                  2
# 19     3.6             Acviss  Android Developer   500000                  2
# 20     4.1            Fresher  Android Developer   408000                  2
#
#      Location Employment Status Job Roles
# 16  Bangalore         Full Time   Android
# 17  Bangalore         Full Time   Android
# 18  Bangalore         Full Time   Android
# 19  Bangalore         Full Time   Android
# 20  Bangalore         Full Time   Android

# %%
#los diferentes metodos de rellenar o imputacion

# seleccionar la columna
ftr_name = 'Rating'

# rellenar con un valor dado
df_imputed["X_0_numerico"] = df_imputed[ftr_name].fillna(0) # imputar con un numero para todos los ausentes
df_imputed["X_0_texto"] = df_imputed[ftr_name].fillna('0')# imputar con un texto para todos los ausentes

# relleno segun contexto
df_imputed["X_promedio"] = df_imputed[ftr_name].fillna(df_imputed[ftr_name].mean())# imputar con un numero resultado de obtewner el promedio de la columna para todos los ausentes
df_imputed["X_mediana"] = df_imputed[ftr_name].fillna(df_imputed[ftr_name].median())# imputar con un numero resultado de obtewner la mediano de la columna para todos los ausentes
df_imputed["X_forward"] = df_imputed[ftr_name].fillna(method="ffill") # imputar con el anterior valor en la columna para todos los ausentes
df_imputed["X_backward"] = df_imputed[ftr_name].fillna(method="backfill")# imputar con el posterior valor en la columna para todos los ausentes

# ver resultado de las estrategias de imputacion
columnas_resultado = [ftr_name,"X_0_numerico","X_0_texto","X_promedio","X_mediana","X_forward","X_backward"]
df_imputed[columnas_resultado][16:21]
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16236\3296314481.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_imputed["X_forward"] = df_imputed[ftr_name].fillna(method="ffill") # imputar con el anterior valor en la columna para todos los ausentes
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16236\3296314481.py:14: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_imputed["X_backward"] = df_imputed[ftr_name].fillna(method="backfill")# imputar con el posterior valor en la columna para todos los ausentes
#     Rating  X_0_numerico  X_0_texto  X_promedio  X_mediana  X_forward  \
# 16     3.6           3.6        3.6         3.6        3.6        3.6
# 17     3.7           3.7        3.7         3.7        3.7        3.7
# 18     4.0           4.0        4.0         4.0        4.0        4.0
# 19     3.6           3.6        3.6         3.6        3.6        3.6
# 20     4.1           4.1        4.1         4.1        4.1        4.1
#
#     X_backward
# 16         3.6
# 17         3.7
# 18         4.0
# 19         3.6
# 20         4.1

# %%
nombre_columna = "Company Name"
df_imputed[df_imputed[nombre_columna].isnull()] # el registro vacio
# Out:
#        Rating Company Name                      Job Title   Salary  \
# 13760     4.0          NaN  Software Development Engineer  1188000
#
#        Salaries Reported   Location Employment Status Job Roles  X_0_numerico  \
# 13760                  1  Bangalore         Full Time       SDE           4.0
#
#        X_0_texto  X_promedio  X_mediana  X_forward  X_backward
# 13760        4.0         4.0        4.0        4.0         4.0

# %%
df_imputed.iloc[67:72] # fila 69 es la que posee un valor vacio
# Out:
#     Rating                Company Name          Job Title   Salary  \
# 67     3.9                      HARMAN  Android Developer   700000
# 68     3.2                   Oust Labs  Android Developer   396000
# 69     4.0             Kaskeid Designs  Android Developer   264000
# 70     3.6        TruKKer Technologies  Android Developer   500000
# 71     3.3  Datamatics Global Services  Android Developer  1000000
#
#     Salaries Reported   Location Employment Status Job Roles  X_0_numerico  \
# 67                  2  Bangalore         Full Time   Android           3.9
# 68                  2  Bangalore         Full Time   Android           3.2
# 69                  2  Bangalore         Full Time   Android           4.0
# 70                  2  Bangalore         Full Time   Android           3.6
# 71                  2  Bangalore         Full Time   Android           3.3
#
#     X_0_texto  X_promedio  X_mediana  X_forward  X_backward
# 67        3.9         3.9        3.9        3.9         3.9
# 68        3.2         3.2        3.2        3.2         3.2
# 69        4.0         4.0        4.0        4.0         4.0
# 70        3.6         3.6        3.6        3.6         3.6
# 71        3.3         3.3        3.3        3.3         3.3

# %%
#los diferentes metodos de rellenar o imputacion
nombre_columna = "Company Name"

# rellenar con un valor dado
df_imputed["X_0_numerico"] = df_imputed[nombre_columna].fillna(0) # imputar con un numero para todos los ausentes
df_imputed["X_cualquier_texto"] = df_imputed[nombre_columna].fillna('Alcaldia')# imputar con un texto para todos los ausentes

# relleno segun contexto
df_imputed["X_forward"] = df_imputed[nombre_columna].fillna(method="ffill") # imputar con el anterior valor en la columna para todos los ausentes
df_imputed["X_backward"] = df_imputed[nombre_columna].fillna(method="backfill")# imputar con el posterior valor en la columna para todos los ausentes

# ver resultado de las estrategias de imputacion
columnas_resultado = [nombre_columna,"X_0_numerico","X_cualquier_texto","X_forward","X_backward"]
df_imputed[columnas_resultado][67:72]
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16236\3135418756.py:9: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_imputed["X_forward"] = df_imputed[nombre_columna].fillna(method="ffill") # imputar con el anterior valor en la columna para todos los ausentes
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16236\3135418756.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_imputed["X_backward"] = df_imputed[nombre_columna].fillna(method="backfill")# imputar con el posterior valor en la columna para todos los ausentes
#                   Company Name                X_0_numerico  \
# 67                      HARMAN                      HARMAN
# 68                   Oust Labs                   Oust Labs
# 69             Kaskeid Designs             Kaskeid Designs
# 70        TruKKer Technologies        TruKKer Technologies
# 71  Datamatics Global Services  Datamatics Global Services
#
#              X_cualquier_texto                   X_forward  \
# 67                      HARMAN                      HARMAN
# 68                   Oust Labs                   Oust Labs
# 69             Kaskeid Designs             Kaskeid Designs
# 70        TruKKer Technologies        TruKKer Technologies
# 71  Datamatics Global Services  Datamatics Global Services
#
#                     X_backward
# 67                      HARMAN
# 68                   Oust Labs
# 69             Kaskeid Designs
# 70        TruKKer Technologies
# 71  Datamatics Global Services

# %% [markdown]
# ## Variables dummy

# %%
df_dummies = df.copy() # sacando una copia del df original

# %%
df_dummies["Employment Status"].values # reviisar posibles valores que puede haber en columna seleccionada
# Out:
# array(['Full Time', 'Full Time', 'Full Time', ..., 'Full Time',
#        'Full Time', 'Full Time'], dtype=object)

# %%
df_dummies["Employment Status"].value_counts()# reviisar posibles valores que puede haber en columna seleccionada
# Out:
# Employment Status
# Full Time     20083
# Intern         2106
# Contractor      548
# Trainee          33
# Name: count, dtype: int64

# %%
vars_dummies = pd.get_dummies(
    df_dummies["Employment Status"], # la columna original
    prefix="Empl_status:" # agrega un prefijo al nuevo nombre de la columna
    ) # obtener las columnas dummies a pártir de columna referencia
vars_dummies
# Out:
#        Empl_status:_Contractor  Empl_status:_Full Time  Empl_status:_Intern  \
# 0                        False                    True                False
# 1                        False                    True                False
# 2                        False                    True                False
# 3                        False                    True                False
# 4                        False                    True                False
# ...                        ...                     ...                  ...
# 22765                    False                    True                False
# 22766                    False                    True                False
# 22767                    False                    True                False
# 22768                    False                    True                False
# 22769                    False                    True                False
#
#        Empl_status:_Trainee
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 22765                 False
# 22766                 False
# 22767                 False
# 22768                 False
# 22769                 False
#
# [22770 rows x 4 columns]

# %%
# 1er paso - convertir en dummies columna categorica (entrega tantas columnas como categorias tenga la columna original)
vars_dummies = pd.get_dummies(
    df_dummies["Employment Status"], 
    prefix="Empl_status:"
    ) # obtener las columnas dummies a pártir de columna referencia

# 2do paso - borrar columna original que se convirtió a dummies
df_drop_var = df_dummies.drop(
    ["Employment Status"], 
    axis = 1 # eliminar columnas
    ) # construir las dummies apartir del status

# 3er paso -  concatenar (pegar columnas a la derecha) el df con columnas dummies
df_dummies = pd.concat(
    [df_drop_var, vars_dummies], 
    axis = 1 # pegar por la derecha la tabla construida de dummies (pegar por columna)
    ) 

# revisar encabezado con reusltado
df_dummies.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Job Roles  Empl_status:_Contractor  \
# 0                  3  Bangalore   Android                    False
# 1                  3  Bangalore   Android                    False
# 2                  3  Bangalore   Android                    False
# 3                  3  Bangalore   Android                    False
# 4                  3  Bangalore   Android                    False
#
#    Empl_status:_Full Time  Empl_status:_Intern  Empl_status:_Trainee
# 0                    True                False                 False
# 1                    True                False                 False
# 2                    True                False                 False
# 3                    True                False                 False
# 4                    True                False                 False

# %% [markdown]
# ## Ordenar el dataframe

# %%
df.head(5)
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
# ordenemelo utilizando la columna de formma ascendente
df.sort_values(
    by=['Rating'], # segun la informacion de la colum
    ascending=True # de forma ascendente (de menor a mayor)
    )
# Out:
#        Rating                  Company Name  \
# 2823      1.0                        TellMe
# 10186     1.0        Doctily Digital Health
# 20182     1.0      i-soft software solution
# 7998      1.0                   VRN Systems
# 18596     1.0       Rohan Motors (Dehradun)
# ...       ...                           ...
# 9433      5.0                     Provility
# 5095      5.0       Talent Zone Consultants
# 85        5.0  Blooms Mobility Technologies
# 14277     5.0         DataWENS Technologies
# 84        5.0               Proven Solution
#
#                                   Job Title   Salary  Salaries Reported  \
# 2823           Android Developer Contractor   144000                  1
# 10186                 Senior Java Developer  1500000                  1
# 20182                         Test Engineer   500000                  1
# 7998                          IOS Developer  1100000                  1
# 18596   Software Development Engineer (SDE)   500000                  1
# ...                                     ...      ...                ...
# 9433                  Junior Java Developer   300000                  1
# 5095                    Front End Developer   600000                  1
# 85                        Android Developer   300000                  1
# 14277  Senior Software Development Engineer   648000                  1
# 84                        Android Developer   500000                  1
#
#         Location Employment Status Job Roles
# 2823        Pune        Contractor   Android
# 10186  Hyderabad         Full Time      Java
# 20182  Hyderabad         Full Time   Testing
# 7998   New Delhi         Full Time       IOS
# 18596  New Delhi         Full Time       SDE
# ...          ...               ...       ...
# 9433     Chennai         Full Time      Java
# 5095   Bangalore         Full Time  Frontend
# 85     Bangalore         Full Time   Android
# 14277    Chennai         Full Time       SDE
# 84     Bangalore         Full Time   Android
#
# [22770 rows x 8 columns]

# %%
# ordenemelo utilizando la columna de formma ascendente
df.sort_values(
    by=['Rating'], # segun la informacion de la column
    ascending=False # de forma descendente (de mayor a menor)
    )
# Out:
#        Rating             Company Name                            Job Title  \
# 5095      5.0  Talent Zone Consultants                  Front End Developer
# 30        5.0            powerplay app           Android Developer - Intern
# 63        5.0            powerplay app                    Android Developer
# 1512      5.0             BroChill.com             Senior Android Developer
# 16753     5.0                 DeepMind  Software Development Engineer (SDE)
# ...       ...                      ...                                  ...
# 1443      1.0        Avantech Web Grid                    Android Developer
# 6328      1.0             SAMA Telecom                  Front End Developer
# 20039     1.0          YV Technologies                        Test Engineer
# 17437     1.0                   Buzz09        Software Development Engineer
# 8770      1.0                 Hidoc Dr                    Ios App Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# 5095    600000                  1  Bangalore         Full Time  Frontend
# 30      396000                  2  Bangalore            Intern   Android
# 63     1000000                  2  Bangalore         Full Time   Android
# 1512    400000                  1  Hyderabad         Full Time   Android
# 16753   600000                  1     Mumbai         Full Time       SDE
# ...        ...                ...        ...               ...       ...
# 1443    500000                  1  Hyderabad         Full Time   Android
# 6328    100000                  1  Hyderabad         Full Time  Frontend
# 20039   300000                  1  Hyderabad         Full Time   Testing
# 17437   228000                  1  New Delhi         Full Time       SDE
# 8770    612000                  1       Pune         Full Time       IOS
#
# [22770 rows x 8 columns]

# %%
df.sort_values(
    by=['Location']
    ) # ascendente (de menor a mayor o de A a la Z) : ascending=True
# cuando hay vacios los suele dejar al final
# Out:
#        Rating                 Company Name  \
# 0         3.8                       Sasken
# 12149     4.0          JPMorgan Chase & Co
# 12150     4.0                        Hdref
# 12151     4.0                    SAP Ariba
# 12152     3.4                   Joy Global
# ...       ...                          ...
# 19681     4.0                     Barclays
# 19682     3.9                       AArete
# 19683     4.1                      Xoriant
# 19613     3.9  Mercedes-Benz International
# 19240     3.3                    SmartServ
#
#                                           Job Title   Salary  \
# 0                                 Android Developer   400000
# 12149                 Software Development Engineer  1200000
# 12150                 Software Development Engineer  1200000
# 12151                 Software Development Engineer  1200000
# 12152                 Software Development Engineer  1200000
# ...                                             ...      ...
# 19681        Software Development Engineer (SDE) II  1300000
# 19682        Software Development Engineer (SDE) II   200000
# 19683        Software Development Engineer (SDE) II  1700000
# 19613  Software Development Engineer In Test (SDET)  5000000
# 19240              Software Development Engineer II  1200000
#
#        Salaries Reported   Location Employment Status Job Roles
# 0                      3  Bangalore         Full Time   Android
# 12149                  1  Bangalore         Full Time       SDE
# 12150                  1  Bangalore         Full Time       SDE
# 12151                  1  Bangalore         Full Time       SDE
# 12152                  1  Bangalore         Full Time       SDE
# ...                  ...        ...               ...       ...
# 19681                  1       Pune         Full Time       SDE
# 19682                  1       Pune         Full Time       SDE
# 19683                  1       Pune         Full Time       SDE
# 19613                  1       Pune         Full Time       SDE
# 19240                  1       Pune         Full Time       SDE
#
# [22770 rows x 8 columns]

# %%
df.sort_values(
    by=['Location'], 
    ascending=False # descendente (de mayor a menor o de Z a la A) : ascending=False
    ) 
# cuando hay vacios los suele dejar al final
# Out:
#        Rating            Company Name                Job Title   Salary  \
# 7057      4.0               GeekSquad      Front End Developer   500000
# 2870      3.8          Megapolis Pune        Android Developer   156000
# 2877      4.1       Android de México        Android Developer   228000
# 2876      3.0  Intuition IT Solutions        Android Developer   200000
# 2875      2.2               LogicBits        Android Developer   168000
# ...       ...                     ...                      ...      ...
# 11241     4.0            Focus Softek  Python/Django Developer   500000
# 11242     3.5            Byte Academy  Python/Django Developer   200000
# 11243     5.0      Tudo Technologoies  Python/Django Developer   288000
# 11244     3.2                     IAS  Python/Django Developer  1152000
# 22769     3.8         Thomson Reuters  Associate Web Developer   300000
#
#        Salaries Reported   Location Employment Status Job Roles
# 7057                   1       Pune         Full Time  Frontend
# 2870                   1       Pune         Full Time   Android
# 2877                   1       Pune         Full Time   Android
# 2876                   1       Pune         Full Time   Android
# 2875                   1       Pune         Full Time   Android
# ...                  ...        ...               ...       ...
# 11241                  1  Bangalore         Full Time    Python
# 11242                  1  Bangalore         Full Time    Python
# 11243                  1  Bangalore         Full Time    Python
# 11244                  1  Bangalore         Full Time    Python
# 22769                  7  Bangalore         Full Time       Web
#
# [22770 rows x 8 columns]

# %%
# ordenar por varias columnas
df.sort_values(
    by=['Rating','Location','Salary','Salaries Reported'], 
    ascending=False # desc
    )
# Out:
#        Rating             Company Name  \
# 19713     5.0      doLoop Technologies
# 18915     5.0                On Campus
# 6872      5.0  Talent Zone Consultants
# 6994      5.0          ThoughtMiracles
# 3703      5.0         Scalent Infotech
# ...       ...                      ...
# 11155     1.0               PRIME SHIP
# 21927     1.0          Corpyogi System
# 4596      1.0        InnoCirc Ventures
# 21832     1.0     Syflani Technologies
# 5578      1.0                Numa Soft
#
#                                              Job Title   Salary  \
# 19713          Principal Software Development Engineer  2100000
# 18915                    Software Development Engineer  1700000
# 6872                               Front End Developer  1500000
# 6994                               Front End Developer  1500000
# 3703                                  Backend Engineer  1000000
# ...                                                ...      ...
# 11155                                 Python Developer   120000
# 21927                                    Web Developer   108000
# 4596   Database Administrator (Database Administrator)   100000
# 21832                                    Web Developer    72000
# 5578                      Front-End Developer - Intern    36000
#
#        Salaries Reported   Location Employment Status Job Roles
# 19713                  1       Pune         Full Time       SDE
# 18915                  1       Pune         Full Time       SDE
# 6872                   1       Pune         Full Time  Frontend
# 6994                   1       Pune         Full Time  Frontend
# 3703                   1       Pune         Full Time   Backend
# ...                  ...        ...               ...       ...
# 11155                  1  Bangalore         Full Time    Python
# 21927                  1  Bangalore         Full Time       Web
# 4596                   1  Bangalore         Full Time  Database
# 21832                  2  Bangalore         Full Time       Web
# 5578                   1  Bangalore            Intern  Frontend
#
# [22770 rows x 8 columns]

# %%
# prueba
df.sort_values(
    by=['Rating','Location','Salary','Salaries Reported'], 
    ascending=False
    )[df.Rating == 1.0][0:15] # ordenar por varias columnas
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16236\4151213170.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.sort_values(
#        Rating                 Company Name  \
# 19217     1.0                        ZEVEX
# 8770      1.0                     Hidoc Dr
# 8609      1.0               Vivant (India)
# 8717      1.0               Vivant (India)
# 2823      1.0                       TellMe
# 2594      1.0        Tsysinfo Technologies
# 7998      1.0                  VRN Systems
# 2443      1.0                        Codoc
# 6805      1.0       Wishbox Communications
# 17968     1.0                 Dangal Games
# 2274      1.0                   Fitness365
# 17691     1.0  Deutscher Gewerkschaftsbund
# 18596     1.0      Rohan Motors (Dehradun)
# 2115      1.0                  Rollz India
# 3969      1.0                      Jeebley
#
#                                  Job Title   Salary  Salaries Reported  \
# 19217      Software Development Engineer I  1100000                  1
# 8770                     Ios App Developer   612000                  1
# 8609                         IOS Developer   400000                  1
# 8717                  Junior IOS Developer   400000                  1
# 2823          Android Developer Contractor   144000                  1
# 2594                     Android Developer   132000                  2
# 7998                         IOS Developer  1100000                  1
# 2443                     Android Developer  1000000                  1
# 6805                   Front End Developer   800000                  1
# 17968      Software Development Engineer I   500000                  2
# 2274                     Android Developer   500000                  1
# 17691        Software Development Engineer   500000                  1
# 18596  Software Development Engineer (SDE)   500000                  1
# 2115                     Android Developer   480000                  1
# 3969                     Backend Developer   400000                  1
#
#         Location Employment Status Job Roles
# 19217       Pune         Full Time       SDE
# 8770        Pune         Full Time       IOS
# 8609        Pune         Full Time       IOS
# 8717        Pune         Full Time       IOS
# 2823        Pune        Contractor   Android
# 2594        Pune         Full Time   Android
# 7998   New Delhi         Full Time       IOS
# 2443   New Delhi         Full Time   Android
# 6805   New Delhi         Full Time  Frontend
# 17968  New Delhi         Full Time       SDE
# 2274   New Delhi         Full Time   Android
# 17691  New Delhi         Full Time       SDE
# 18596  New Delhi         Full Time       SDE
# 2115   New Delhi         Full Time   Android
# 3969   New Delhi         Full Time   Backend

# %% [markdown]
# ## Filtrar por columna o fila

# %% [markdown]
# ### filtrar por columnas (axis 1)

# %%
df.filter(
    items=['Rating', 'Salary'], 
    axis=1 # filtrar usando el axis 1 indica que los items filtrados columnas
    )
# Out:
#        Rating   Salary
# 0         3.8   400000
# 1         4.5   400000
# 2         4.0  1000000
# 3         3.8   300000
# 4         4.4   600000
# ...       ...      ...
# 22765     4.7   200000
# 22766     4.0   300000
# 22767     4.1   192000
# 22768     4.1   300000
# 22769     3.8   300000
#
# [22770 rows x 2 columns]

# %%
df.filter(
    like='Job', 
    axis=1
    ) # seleccion columnas segun coincida con un patron
# Out:
#                       Job Title Job Roles
# 0             Android Developer   Android
# 1             Android Developer   Android
# 2             Android Developer   Android
# 3             Android Developer   Android
# 4             Android Developer   Android
# ...                         ...       ...
# 22765             Web Developer       Web
# 22766             Web Developer       Web
# 22767  Full Stack Web Developer       Web
# 22768  Full Stack Web Developer       Web
# 22769   Associate Web Developer       Web
#
# [22770 rows x 2 columns]

# %%
df.filter(
    like='e', 
    axis=1
    ) # seleccion columnas segun coincida con un patron
# Out:
#                            Company Name                 Job Title  \
# 0                                Sasken         Android Developer
# 1      Advanced Millennium Technologies         Android Developer
# 2                             Unacademy         Android Developer
# 3                    SnapBizz Cloudtech         Android Developer
# 4                Appoids Tech Solutions         Android Developer
# ...                                 ...                       ...
# 22765                  Expert Solutions             Web Developer
# 22766           Nextgen Innovation Labs             Web Developer
# 22767                           Fresher  Full Stack Web Developer
# 22768                         Accenture  Full Stack Web Developer
# 22769                   Thomson Reuters   Associate Web Developer
#
#        Salaries Reported Employment Status Job Roles
# 0                      3         Full Time   Android
# 1                      3         Full Time   Android
# 2                      3         Full Time   Android
# 3                      3         Full Time   Android
# 4                      3         Full Time   Android
# ...                  ...               ...       ...
# 22765                  1         Full Time       Web
# 22766                  1         Full Time       Web
# 22767                 13         Full Time       Web
# 22768                  7         Full Time       Web
# 22769                  7         Full Time       Web
#
# [22770 rows x 5 columns]

# %%
df.filter(
    regex='e$', # las que terminen en 'e'
    axis=1
    ) # seleccionar las que coincidancon un patron utilzando expresiones regulares
# Out:
#                            Company Name                 Job Title
# 0                                Sasken         Android Developer
# 1      Advanced Millennium Technologies         Android Developer
# 2                             Unacademy         Android Developer
# 3                    SnapBizz Cloudtech         Android Developer
# 4                Appoids Tech Solutions         Android Developer
# ...                                 ...                       ...
# 22765                  Expert Solutions             Web Developer
# 22766           Nextgen Innovation Labs             Web Developer
# 22767                           Fresher  Full Stack Web Developer
# 22768                         Accenture  Full Stack Web Developer
# 22769                   Thomson Reuters   Associate Web Developer
#
# [22770 rows x 2 columns]

# %% [markdown]
# ### filtrar por fila (index) (axis = 0)

# %%
df.filter(
    items=[227,267], 
    axis=0
    )#  filtrar por fila utilizando el axis 0
# Out:
#      Rating             Company Name          Job Title   Salary  \
# 227     5.0  Talent Zone Consultants  Android Developer   400000
# 267     3.4                News Corp  Android Developer  1600000
#
#      Salaries Reported   Location Employment Status Job Roles
# 227                  1  Bangalore         Full Time   Android
# 267                  1  Bangalore         Full Time   Android

# %%
df.filter(
    like='227', 
    axis=0
    ) #  filtrar por fila utilizando el axis 0 que coincidan en el nombre del indice
# Out:
#        Rating                                Company Name  \
# 227       5.0                     Talent Zone Consultants
# 1227      4.3                               Full Creative
# 2227      3.1     Samsung R&D Institute India - Bangalore
# 2270      3.9                                        IIFL
# 2271      3.8  Associates for Bilingual Child Development
# ...       ...                                         ...
# 22765     4.7                            Expert Solutions
# 22766     4.0                     Nextgen Innovation Labs
# 22767     4.1                                     Fresher
# 22768     4.1                                   Accenture
# 22769     3.8                             Thomson Reuters
#
#                       Job Title   Salary  Salaries Reported   Location  \
# 227           Android Developer   400000                  1  Bangalore
# 1227           Android - Intern   180000                  1    Chennai
# 2227          Android Developer  1000000                  1  New Delhi
# 2270          Android Developer   600000                  1  New Delhi
# 2271          Android Developer   288000                  1  New Delhi
# ...                         ...      ...                ...        ...
# 22765             Web Developer   200000                  1  Bangalore
# 22766             Web Developer   300000                  1  Bangalore
# 22767  Full Stack Web Developer   192000                 13  Bangalore
# 22768  Full Stack Web Developer   300000                  7  Bangalore
# 22769   Associate Web Developer   300000                  7  Bangalore
#
#       Employment Status Job Roles
# 227           Full Time   Android
# 1227             Intern   Android
# 2227          Full Time   Android
# 2270          Full Time   Android
# 2271          Full Time   Android
# ...                 ...       ...
# 22765         Full Time       Web
# 22766         Full Time       Web
# 22767         Full Time       Web
# 22768         Full Time       Web
# 22769         Full Time       Web
#
# [123 rows x 8 columns]

# %%
df.filter(
    regex = '227$', 
    axis = 0
    ) # todas las que el indice termine en 227
# Out:
#        Rating                             Company Name  \
# 227       5.0                  Talent Zone Consultants
# 1227      4.3                            Full Creative
# 2227      3.1  Samsung R&D Institute India - Bangalore
# 3227      4.2                              HackerEarth
# 4227      4.0                              J.P. Morgan
# 5227      3.2                                Reward360
# 6227      3.6                     Helical IT Solutions
# 7227      4.6                               Kristal.AI
# 8227      3.9                                  QuyTech
# 9227      4.0                   Intellect Design Arena
# 10227     3.9                 Conceptwave Software Inc
# 11227     4.1         Ericsson IT Solutions & Services
# 12227     3.7                                    Subex
# 13227     4.4                               IIT Kanpur
# 14227     5.0                            The HK Online
# 15227     5.0                          heresy infotech
# 16227     4.7                    Google Summer of Code
# 17227     3.9                                  Shubham
# 18227     3.7                             REVE Systems
# 19227     3.8                        Dassault Systemes
# 20227     3.9                                     Citi
# 21227     4.3                                   Luxoft
# 22227     5.0                  Talent Zone Consultants
#
#                                     Job Title   Salary  Salaries Reported  \
# 227                         Android Developer   400000                  1
# 1227                         Android - Intern   180000                  1
# 2227                        Android Developer  1000000                  1
# 3227      Software Engineer, Backend - Intern   468000                  1
# 4227            Sybase Database Administrator  1900000                  2
# 5227                      Front End Developer   600000                  1
# 6227                      Front End Developer   252000                  1
# 7227                            IOS Developer  1500000                  1
# 8227                     Senior IOS Developer   984000                  1
# 9227                    Senior Java Developer   500000                  1
# 10227                   Senior Java Developer   100000                  1
# 11227                 Python/Django Developer   500000                  1
# 12227           Software Development Engineer  1300000                  1
# 13227  Software Development Engineer - Intern    48000                  1
# 14227     Software Development Engineer (SDE)   200000                  1
# 15227     Software Development Engineer (SDE)  1176000                  1
# 16227     Software Development Engineer (SDE)   300000                  1
# 17227  Software Development Engineer - Intern   936000                  1
# 18227         Engineer - Software Development   700000                  1
# 19227        Software Development Enginner-||  1400000                  1
# 20227                           Test Engineer   708000                  1
# 21227                           Test Engineer  1900000                  1
# 22227                           Web Developer   500000                  1
#
#              Location Employment Status Job Roles
# 227         Bangalore         Full Time   Android
# 1227          Chennai            Intern   Android
# 2227        New Delhi         Full Time   Android
# 3227        Bangalore            Intern   Backend
# 4227        Bangalore         Full Time  Database
# 5227        Bangalore         Full Time  Frontend
# 6227        Hyderabad         Full Time  Frontend
# 7227        Bangalore         Full Time       IOS
# 8227        New Delhi         Full Time       IOS
# 9227          Chennai         Full Time      Java
# 10227       Hyderabad         Full Time      Java
# 11227       Bangalore         Full Time    Python
# 12227       Bangalore         Full Time       SDE
# 13227       Bangalore            Intern       SDE
# 14227         Chennai         Full Time       SDE
# 15227       Hyderabad         Full Time       SDE
# 16227  Madhya Pradesh         Full Time       SDE
# 17227       New Delhi            Intern       SDE
# 18227       New Delhi         Full Time       SDE
# 19227            Pune         Full Time       SDE
# 20227       Hyderabad         Full Time   Testing
# 21227       Bangalore         Full Time   Testing
# 22227       Bangalore         Full Time       Web

# %% [markdown]
# ## Query con pandas (Consulta)

# %% [markdown]
# * seleccionar columnas

# %%
df['Salary']
# Out:
# 0         400000
# 1         400000
# 2        1000000
# 3         300000
# 4         600000
#           ...
# 22765     200000
# 22766     300000
# 22767     192000
# 22768     300000
# 22769     300000
# Name: Salary, Length: 22770, dtype: int64

# %%
df.Salary
# Out:
# 0         400000
# 1         400000
# 2        1000000
# 3         300000
# 4         600000
#           ...
# 22765     200000
# 22766     300000
# 22767     192000
# 22768     300000
# 22769     300000
# Name: Salary, Length: 22770, dtype: int64

# %% [markdown]
# 1ra forma

# %%
df.filter(items=['Salary','Rating'], axis = 1) # filtrar por columnas
# Out:
#         Salary  Rating
# 0       400000     3.8
# 1       400000     4.5
# 2      1000000     4.0
# 3       300000     3.8
# 4       600000     4.4
# ...        ...     ...
# 22765   200000     4.7
# 22766   300000     4.0
# 22767   192000     4.1
# 22768   300000     4.1
# 22769   300000     3.8
#
# [22770 rows x 2 columns]

# %% [markdown]
# 2da forma

# %%
df[['Salary','Rating']] # seleccionar columnas del dataframe a seleccionar
# Out:
#         Salary  Rating
# 0       400000     3.8
# 1       400000     4.5
# 2      1000000     4.0
# 3       300000     3.8
# 4       600000     4.4
# ...        ...     ...
# 22765   200000     4.7
# 22766   300000     4.0
# 22767   192000     4.1
# 22768   300000     4.1
# 22769   300000     3.8
#
# [22770 rows x 2 columns]

# %% [markdown]
# * realizar descriptivo

# %%
df.Salary.describe() # descriptivo rapido de la informacion
# Out:
# count    2.277000e+04
# mean     6.953872e+05
# std      8.843990e+05
# min      2.112000e+03
# 25%      3.000000e+05
# 50%      5.000000e+05
# 75%      9.000000e+05
# max      9.000000e+07
# Name: Salary, dtype: float64

# %% [markdown]
# * evaluar condiciones en cada fila

# %%
df['Salary'] >  490000 # genera una columna con la evaluación a la condición # WHERE
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 22765    False
# 22766    False
# 22767    False
# 22768    False
# 22769    False
# Name: Salary, Length: 22770, dtype: bool

# %%
df['Rating'] > 4.3
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 22765     True
# 22766    False
# 22767    False
# 22768    False
# 22769    False
# Name: Rating, Length: 22770, dtype: bool

# %%
# copia dataframe
df_test_001 = df.copy()
# crear nueva columna con condiciones
df_test_001['condicion_1'] = df['Salary'] > 490000
df_test_001['condicion_2'] = df['Rating'] > 4.3
df_test_001['condicion_INTERSECCION'] = (df['Salary'] > 490000) & (df['Rating'] > 4.3)
df_test_001['condicion_UNION'] = (df['Salary'] > 490000) | (df['Rating'] > 4.3)


# revisar resultado
df_test_001[['Salary','Rating','condicion_1','condicion_2','condicion_INTERSECCION','condicion_UNION']]
# Out:
#         Salary  Rating  condicion_1  condicion_2  condicion_INTERSECCION  \
# 0       400000     3.8        False        False                   False
# 1       400000     4.5        False         True                   False
# 2      1000000     4.0         True        False                   False
# 3       300000     3.8        False        False                   False
# 4       600000     4.4         True         True                    True
# ...        ...     ...          ...          ...                     ...
# 22765   200000     4.7        False         True                   False
# 22766   300000     4.0        False        False                   False
# 22767   192000     4.1        False        False                   False
# 22768   300000     4.1        False        False                   False
# 22769   300000     3.8        False        False                   False
#
#        condicion_UNION
# 0                False
# 1                 True
# 2                 True
# 3                False
# 4                 True
# ...                ...
# 22765             True
# 22766            False
# 22767            False
# 22768            False
# 22769            False
#
# [22770 rows x 6 columns]

# %% [markdown]
# * filtrar según se evalua condiciones

# %%
# condiciones logicas
condicion1 = df['Salary'] > 490000
condicion2 = df['Rating'] > 4.3

# filtrar según condicion evaluada
df[condicion1 & condicion2] # and (& se usa para la interseccion :  cumplir al mismo tiempo ambas)
# Out:
#        Rating                 Company Name          Job Title   Salary  \
# 4         4.4       Appoids Tech Solutions  Android Developer   600000
# 27        4.9             Retranz Infolabs  Android Developer   500000
# 32        4.6                 Masai School  Android Developer   500000
# 50        4.8        CRK Gida Technologies  Android Developer   700000
# 63        5.0                powerplay app  Android Developer  1000000
# ...       ...                          ...                ...      ...
# 22701     4.4       Silvan Innovation Labs      Web Developer   900000
# 22707     4.6  Regal Software Technologies      Web Developer  1400000
# 22714     4.4        Loyalytics Consulting      Web Developer   600000
# 22742     5.0                    Leanpitch      Web Developer   500000
# 22763     4.4               Unicon Systems      Web Developer   500000
#
#        Salaries Reported   Location Employment Status Job Roles
# 4                      3  Bangalore         Full Time   Android
# 27                     2  Bangalore         Full Time   Android
# 32                     2  Bangalore         Full Time   Android
# 50                     2  Bangalore         Full Time   Android
# 63                     2  Bangalore         Full Time   Android
# ...                  ...        ...               ...       ...
# 22701                  1  Bangalore         Full Time       Web
# 22707                  1  Bangalore         Full Time       Web
# 22714                  1  Bangalore         Full Time       Web
# 22742                  1  Bangalore         Full Time       Web
# 22763                  1  Bangalore         Full Time       Web
#
# [1894 rows x 8 columns]

# %%
condicion1 = df['Salary'] > 490000
condicion2 = df['Rating'] > 4.3

df[condicion1 | condicion2] # OR (| union que se cumplan por lo menos una de las dos condicioens)
# Out:
#        Rating                      Company Name               Job Title  \
# 1         4.5  Advanced Millennium Technologies       Android Developer
# 2         4.0                         Unacademy       Android Developer
# 4         4.4            Appoids Tech Solutions       Android Developer
# 9         3.6   Endeavour Software Technologies       Android Developer
# 12        3.7                             Wibmo       Android Developer
# ...       ...                               ...                     ...
# 22758     4.5             Blu Ocean Innovations  Web Developer - Intern
# 22761     4.6                      Masai School           Web Developer
# 22763     4.4                    Unicon Systems           Web Developer
# 22764     5.0                            BJSHub           Web Developer
# 22765     4.7                  Expert Solutions           Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# 1       400000                  3  Bangalore         Full Time   Android
# 2      1000000                  3  Bangalore         Full Time   Android
# 4       600000                  3  Bangalore         Full Time   Android
# 9       600000                  3  Bangalore         Full Time   Android
# 12      900000                  2  Bangalore         Full Time   Android
# ...        ...                ...        ...               ...       ...
# 22758   408000                  1  Bangalore            Intern       Web
# 22761   101376                  1  Bangalore         Full Time       Web
# 22763   500000                  1  Bangalore         Full Time       Web
# 22764   400000                  1  Bangalore         Full Time       Web
# 22765   200000                  1  Bangalore         Full Time       Web
#
# [14136 rows x 8 columns]

# %%
df[(df['Salary'] > 490000)|(df['Rating']>4.3)] # utilizar el resultado de evaluar la condicion para filtrar
# Out:
#        Rating                      Company Name               Job Title  \
# 1         4.5  Advanced Millennium Technologies       Android Developer
# 2         4.0                         Unacademy       Android Developer
# 4         4.4            Appoids Tech Solutions       Android Developer
# 9         3.6   Endeavour Software Technologies       Android Developer
# 12        3.7                             Wibmo       Android Developer
# ...       ...                               ...                     ...
# 22758     4.5             Blu Ocean Innovations  Web Developer - Intern
# 22761     4.6                      Masai School           Web Developer
# 22763     4.4                    Unicon Systems           Web Developer
# 22764     5.0                            BJSHub           Web Developer
# 22765     4.7                  Expert Solutions           Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# 1       400000                  3  Bangalore         Full Time   Android
# 2      1000000                  3  Bangalore         Full Time   Android
# 4       600000                  3  Bangalore         Full Time   Android
# 9       600000                  3  Bangalore         Full Time   Android
# 12      900000                  2  Bangalore         Full Time   Android
# ...        ...                ...        ...               ...       ...
# 22758   408000                  1  Bangalore            Intern       Web
# 22761   101376                  1  Bangalore         Full Time       Web
# 22763   500000                  1  Bangalore         Full Time       Web
# 22764   400000                  1  Bangalore         Full Time       Web
# 22765   200000                  1  Bangalore         Full Time       Web
#
# [14136 rows x 8 columns]

# %%
df.query('Salary > 490000 | Rating>4.3') # realizar un query con condicion
# Out:
#        Rating                      Company Name               Job Title  \
# 1         4.5  Advanced Millennium Technologies       Android Developer
# 2         4.0                         Unacademy       Android Developer
# 4         4.4            Appoids Tech Solutions       Android Developer
# 9         3.6   Endeavour Software Technologies       Android Developer
# 12        3.7                             Wibmo       Android Developer
# ...       ...                               ...                     ...
# 22758     4.5             Blu Ocean Innovations  Web Developer - Intern
# 22761     4.6                      Masai School           Web Developer
# 22763     4.4                    Unicon Systems           Web Developer
# 22764     5.0                            BJSHub           Web Developer
# 22765     4.7                  Expert Solutions           Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# 1       400000                  3  Bangalore         Full Time   Android
# 2      1000000                  3  Bangalore         Full Time   Android
# 4       600000                  3  Bangalore         Full Time   Android
# 9       600000                  3  Bangalore         Full Time   Android
# 12      900000                  2  Bangalore         Full Time   Android
# ...        ...                ...        ...               ...       ...
# 22758   408000                  1  Bangalore            Intern       Web
# 22761   101376                  1  Bangalore         Full Time       Web
# 22763   500000                  1  Bangalore         Full Time       Web
# 22764   400000                  1  Bangalore         Full Time       Web
# 22765   200000                  1  Bangalore         Full Time       Web
#
# [14136 rows x 8 columns]

# %%
# hay dos formas de seleccionar o llamar una columna utilizando [] o utilizando el punto
df[df['Salaries Reported'] == df.Rating] # filtrar dataframe cuando cumple condicion
# Out:
#        Rating                                      Company Name  \
# 388       1.0                                 CEWIDUS Solutions
# 555       1.0                                Weinkling Autovity
# 899       1.0                                             Eye-D
# 1218      1.0                                             Lokas
# 1436      1.0                            Grey Line Technologies
# ...       ...                                               ...
# 21570     1.0  Ram Devi Jindal Group of Professional Institutes
# 21927     1.0                                   Corpyogi System
# 22337     1.0                     Crescent Sam Affa Enterprises
# 22596     1.0                           Undigit Media Solutions
# 22633     1.0                                         TGS E-Com
#
#                           Job Title  Salary  Salaries Reported   Location  \
# 388               Android Developer  120000                  1  Bangalore
# 555               Android Developer  200000                  1  Bangalore
# 899    Android Development - Intern  156000                  1  Bangalore
# 1218          Android App Developer  204000                  1    Chennai
# 1436              Android Developer  144000                  1  Hyderabad
# ...                             ...     ...                ...        ...
# 21570                 Test Engineer  400000                  1  Bangalore
# 21927                 Web Developer  108000                  1  Bangalore
# 22337                 Web Developer  432000                  1  Bangalore
# 22596                 Web Developer  204000                  1  Bangalore
# 22633                 Web Developer  400000                  1  Bangalore
#
#       Employment Status Job Roles
# 388           Full Time   Android
# 555           Full Time   Android
# 899              Intern   Android
# 1218          Full Time   Android
# 1436          Full Time   Android
# ...                 ...       ...
# 21570         Full Time   Testing
# 21927         Full Time       Web
# 22337         Full Time       Web
# 22596         Full Time       Web
# 22633         Full Time       Web
#
# [95 rows x 8 columns]

# %%
# uso de comillas especiales para columnas que tienen nombres con espacios `nombre variable`
df.query('`Salaries Reported` == Rating') # obtener mismo resultado de consulta
# Out:
#        Rating                                      Company Name  \
# 388       1.0                                 CEWIDUS Solutions
# 555       1.0                                Weinkling Autovity
# 899       1.0                                             Eye-D
# 1218      1.0                                             Lokas
# 1436      1.0                            Grey Line Technologies
# ...       ...                                               ...
# 21570     1.0  Ram Devi Jindal Group of Professional Institutes
# 21927     1.0                                   Corpyogi System
# 22337     1.0                     Crescent Sam Affa Enterprises
# 22596     1.0                           Undigit Media Solutions
# 22633     1.0                                         TGS E-Com
#
#                           Job Title  Salary  Salaries Reported   Location  \
# 388               Android Developer  120000                  1  Bangalore
# 555               Android Developer  200000                  1  Bangalore
# 899    Android Development - Intern  156000                  1  Bangalore
# 1218          Android App Developer  204000                  1    Chennai
# 1436              Android Developer  144000                  1  Hyderabad
# ...                             ...     ...                ...        ...
# 21570                 Test Engineer  400000                  1  Bangalore
# 21927                 Web Developer  108000                  1  Bangalore
# 22337                 Web Developer  432000                  1  Bangalore
# 22596                 Web Developer  204000                  1  Bangalore
# 22633                 Web Developer  400000                  1  Bangalore
#
#       Employment Status Job Roles
# 388           Full Time   Android
# 555           Full Time   Android
# 899              Intern   Android
# 1218          Full Time   Android
# 1436          Full Time   Android
# ...                 ...       ...
# 21570         Full Time   Testing
# 21927         Full Time       Web
# 22337         Full Time       Web
# 22596         Full Time       Web
# 22633         Full Time       Web
#
# [95 rows x 8 columns]

# %%
# puedo escribir "and" o "&"
# estrictamente ambas condiciones debe cumplir
df.query('(`Salaries Reported` == Rating) and (Salary > 200000)')
# Out:
#        Rating                                      Company Name  \
# 1218      1.0                                             Lokas
# 1443      1.0                                 Avantech Web Grid
# 1507      1.0                                  WinC IT Services
# 1804      1.0                                      NSP Security
# 1817      1.0                                   Anaadih Softech
# ...       ...                                               ...
# 20840     4.0                                               ABB
# 21570     1.0  Ram Devi Jindal Group of Professional Institutes
# 22337     1.0                     Crescent Sam Affa Enterprises
# 22596     1.0                           Undigit Media Solutions
# 22633     1.0                                         TGS E-Com
#
#                       Job Title  Salary  Salaries Reported   Location  \
# 1218      Android App Developer  204000                  1    Chennai
# 1443          Android Developer  500000                  1  Hyderabad
# 1507   Senior Android Developer  600000                  1  Hyderabad
# 1804          Android Developer  228000                  1  New Delhi
# 1817          Android Developer  384000                  1  New Delhi
# ...                         ...     ...                ...        ...
# 20840             Test Engineer  500000                  4  Bangalore
# 21570             Test Engineer  400000                  1  Bangalore
# 22337             Web Developer  432000                  1  Bangalore
# 22596             Web Developer  204000                  1  Bangalore
# 22633             Web Developer  400000                  1  Bangalore
#
#       Employment Status Job Roles
# 1218          Full Time   Android
# 1443          Full Time   Android
# 1507          Full Time   Android
# 1804          Full Time   Android
# 1817          Full Time   Android
# ...                 ...       ...
# 20840         Full Time   Testing
# 21570         Full Time   Testing
# 22337         Full Time       Web
# 22596         Full Time       Web
# 22633         Full Time       Web
#
# [73 rows x 8 columns]

# %%
# puedo escribir "or" o "|"
# por lo menos alguna de las condiciones debe cumplir
df.query('(`Salaries Reported` == Rating) or (Salary > 600000)')
# Out:
#        Rating                                Company Name          Job Title  \
# 2         4.0                                   Unacademy  Android Developer
# 12        3.7                                       Wibmo  Android Developer
# 18        4.0                                 J.P. Morgan  Android Developer
# 22        4.0                                      Nuclei  Android Developer
# 29        3.7                                    KrazyBee  Android Developer
# ...       ...                                         ...                ...
# 22707     4.6                 Regal Software Technologies      Web Developer
# 22724     3.8                                    Fortanix      Web Developer
# 22728     3.9                                      YMedia      Web Developer
# 22748     4.2  Full Time Soluções em Serviços Financeiros      Web Developer
# 22753     4.3                                      rtCamp      Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# 2      1000000                  3  Bangalore         Full Time   Android
# 12      900000                  2  Bangalore         Full Time   Android
# 18     1000000                  2  Bangalore         Full Time   Android
# 22      800000                  2  Bangalore         Full Time   Android
# 29      708000                  2  Bangalore         Full Time   Android
# ...        ...                ...        ...               ...       ...
# 22707  1400000                  1  Bangalore         Full Time       Web
# 22724   900000                  1  Bangalore         Full Time       Web
# 22728   800000                  1  Bangalore         Full Time       Web
# 22748  1176000                  1  Bangalore         Full Time       Web
# 22753   700000                  1  Bangalore         Full Time       Web
#
# [8772 rows x 8 columns]

# %%
# poblacion
poblacion = df.shape[0]
#query 1
# ((`Salaries Reported` == Rating) or (Salary > 600000))
resultado_q1 = df.query('(`Salaries Reported` == Rating) or (Salary > 600000)').shape[0]

#query 2
# not ((`Salaries Reported` == Rating) or (Salary > 600000))
resultado_q2 = poblacion- resultado_q1

print(' el resultado del query 2 (la negacion del query 1) es : {}'.format(resultado_q2))
# Out:
#  el resultado del query 2 (la negacion del query 1) es : 13998

# %%
# puedo escribir "not" o "!"
# niega el cumplimiento de condiciones
df.query('not ((`Salaries Reported` == Rating) or (Salary > 600000))')
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# 5         4.2                        Freelancer         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#        Salary  Salaries Reported   Location Employment Status Job Roles
# 0      400000                  3  Bangalore         Full Time   Android
# 1      400000                  3  Bangalore         Full Time   Android
# 3      300000                  3  Bangalore         Full Time   Android
# 4      600000                  3  Bangalore         Full Time   Android
# 5      100000                  3  Bangalore         Full Time   Android
# ...       ...                ...        ...               ...       ...
# 22765  200000                  1  Bangalore         Full Time       Web
# 22766  300000                  1  Bangalore         Full Time       Web
# 22767  192000                 13  Bangalore         Full Time       Web
# 22768  300000                  7  Bangalore         Full Time       Web
# 22769  300000                  7  Bangalore         Full Time       Web
#
# [13998 rows x 8 columns]

# %%
# la cantidad de registros resultado de la negación resulta en el complemento de la afirmación
no_cumplen = df.query('not ((`Salaries Reported` == Rating) or (Salary > 600000))').shape[0]
si_cumplen = df.query('(`Salaries Reported` == Rating) or (Salary > 600000)').shape[0]
print('los registros que cumnplen con la condicion 1 son {} \n y los registros que cumplen con la condicion 2 son {} \n y en total la cantidad de registros es {}'.format(si_cumplen,no_cumplen,si_cumplen+no_cumplen))
# Out:
# los registros que cumnplen con la condicion 1 son 8772
#  y los registros que cumplen con la condicion 2 son 13998
#  y en total la cantidad de registros es 22770

# %%
# poder conjugar/encadenar/depender varias condiciones
# or |
# and &
# not !
df.query('(`Salaries Reported` == Rating) or not (Salary > 100000)')
# Out:
#        Rating                     Company Name                   Job Title  \
# 5         4.2                       Freelancer           Android Developer
# 13        4.8                     Retail Pulse  Android Developer - Intern
# 24        4.3  Moveinsync Technology Solutions           Android Developer
# 48        3.4               Web Digital Mantra           Android Developer
# 51        3.7              FuGenX Technologies           Android Developer
# ...       ...                              ...                         ...
# 22731     3.0                        Agumentik               Web Developer
# 22745     4.2     TAS Information Intelligence               Web Developer
# 22755     3.1                          Foxmula      Web Developer - Intern
# 22760     4.0                      DiscoverWeb               Web Developer
# 22762     3.9                    Fresher Zones               Web Developer
#
#        Salary  Salaries Reported   Location Employment Status Job Roles
# 5      100000                  3  Bangalore         Full Time   Android
# 13      24000                  2  Bangalore            Intern   Android
# 24     100000                  2  Bangalore         Full Time   Android
# 48     100000                  2  Bangalore         Full Time   Android
# 51     100000                  2  Bangalore         Full Time   Android
# ...       ...                ...        ...               ...       ...
# 22731   72000                  1  Bangalore         Full Time       Web
# 22745  100000                  1  Bangalore         Full Time       Web
# 22755   84000                  1  Bangalore            Intern       Web
# 22760  100000                  1  Bangalore         Full Time       Web
# 22762  100000                  1  Bangalore         Full Time       Web
#
# [1064 rows x 8 columns]

# %% [markdown]
# ## Joins

# %% [markdown]
# ![picture](https://raw.githubusercontent.com/elprincipitogauss/lesson/main/img_joins.jpg)

# %%
# creo dos dataframes

df_izq = pd.DataFrame(
    np.array([['Jairo', 'AD', 120159], ['Felipe', 'FSWD', 444568], ['Marcela', 'UX', 215444], ['Omar', 'FSWD', 421554], ['Celia', 'ADP', 159445]]),
    columns=['Name', 'Job Title Code', 'Salary']
    )


df_der = pd.DataFrame(
    np.array([['AD', 'Android Developer', 'Part time'], ['FSWD', 'Full Stack Web Developer', 'Full time'], ['TE', 'Test Engineer', 'Full time'], ['ADP', 'Advanced Python Developer', 'Part time']]),
    columns=['Job Title Code', 'Job Title Description', 'work']
    )

# %%
df_izq # llave es "Job Title Code"
# Out:
#       Name Job Title Code  Salary
# 0    Jairo             AD  120159
# 1   Felipe           FSWD  444568
# 2  Marcela             UX  215444
# 3     Omar           FSWD  421554
# 4    Celia            ADP  159445

# %%
df_der # llave es "Job Title Code"
# Out:
#   Job Title Code      Job Title Description       work
# 0             AD          Android Developer  Part time
# 1           FSWD   Full Stack Web Developer  Full time
# 2             TE              Test Engineer  Full time
# 3            ADP  Advanced Python Developer  Part time

# %% [markdown]
# * la función se usa para realizar join es pandas.merge (pd.merge)
#
# solo se necesita entender y indicar:
#
# **1. conjuntos de datos a cruzar**
#
# **2. tipo de join**
#
# **3. llaves para realizar cruce (opcional : la funcion pd.merge es capaz de buscar y encontrar la mejor llave si en ambos dataframes tienen el mismo nombres) deben tener el mismo tipo de dato**

# %% [markdown]
#     * pd.merge

# %%
# parametro how indica que tipo de join realizar
# parametro on indica las columnas que quiero utilizar de llaves para el cruce
df_joint_i = pd.merge(
    df_izq, # dataframe de la izquierda
    df_der, # dataframe de la derecha
    how='left', # tipo de join
    on = 'Job Title Code' # llave para realizar cruce
    )
# debo indicar los dataframes, el tipo de join en el HOW y la llave en ON
df_joint_i
# Out:
#       Name Job Title Code  Salary      Job Title Description       work
# 0    Jairo             AD  120159          Android Developer  Part time
# 1   Felipe           FSWD  444568   Full Stack Web Developer  Full time
# 2  Marcela             UX  215444                        NaN        NaN
# 3     Omar           FSWD  421554   Full Stack Web Developer  Full time
# 4    Celia            ADP  159445  Advanced Python Developer  Part time

# %%
df_joint_i = pd.merge(df_izq, df_der, how='right', on = 'Job Title Code')
df_joint_i
# Out:
#      Name Job Title Code  Salary      Job Title Description       work
# 0   Jairo             AD  120159          Android Developer  Part time
# 1  Felipe           FSWD  444568   Full Stack Web Developer  Full time
# 2    Omar           FSWD  421554   Full Stack Web Developer  Full time
# 3     NaN             TE     NaN              Test Engineer  Full time
# 4   Celia            ADP  159445  Advanced Python Developer  Part time

# %%
df_joint_i = pd.merge(df_izq, df_der, how='inner', on = 'Job Title Code')
df_joint_i
# Out:
#      Name Job Title Code  Salary      Job Title Description       work
# 0   Jairo             AD  120159          Android Developer  Part time
# 1  Felipe           FSWD  444568   Full Stack Web Developer  Full time
# 2    Omar           FSWD  421554   Full Stack Web Developer  Full time
# 3   Celia            ADP  159445  Advanced Python Developer  Part time

# %%
df_joint_i = pd.merge(df_izq, df_der, how='outer', on = 'Job Title Code') # full
df_joint_i
# Out:
#       Name Job Title Code  Salary      Job Title Description       work
# 0    Jairo             AD  120159          Android Developer  Part time
# 1    Celia            ADP  159445  Advanced Python Developer  Part time
# 2   Felipe           FSWD  444568   Full Stack Web Developer  Full time
# 3     Omar           FSWD  421554   Full Stack Web Developer  Full time
# 4      NaN             TE     NaN              Test Engineer  Full time
# 5  Marcela             UX  215444                        NaN        NaN

# %% [markdown]
# ## Exportar dataframe

# %%
# exportar a formato excel
# Escribir el DataFrame en un archivo Excel
nombre_archivo_excel = 'archivo_salida.xlsx' # .xlsm .xlsb .xls .xlsx

df_joint_i.to_excel(
    nombre_archivo_excel, # la ruta de salida incluyendo el nombre del archivo
    index=False,  # si exporta los indices de las filas
    sheet_name='resultado_join' #el nombre de la hoja
    )

# %%
# Escribir en un archivo Excel con varias pestañas
nombre_archivo_excel = 'archivo_salida_varias_pestanas.xlsx'

# instruccion para exportar varias tablas en diferentes hojas de un mismo excel
with pd.ExcelWriter(nombre_archivo_excel, engine='openpyxl') as writer:
    df_izq.to_excel(writer, sheet_name='empleados') # crea hoja 'empleados' 
    df_der.to_excel(writer, sheet_name='roles', index=True) # crea hoja 'roles' 
    df_joint_i.to_excel(writer, sheet_name='vista', index=False) # crea hoja 'vista'

# %% [markdown]
# * un archivo de excel tiene un limite maximo de 1,048,576 filas, por lo tanto, cuando uno va a exportar un archivo que supera ese limite es recomendable exportarlo a un archivo plano

# %%
nombre_archivo_salida = 'archivo_salida.txt' # .txt .csv .tsv
# exportar a formato plano 
df_joint_i.to_csv(
    nombre_archivo_salida, # la ruta en donde quiero exportarlo
    sep='>', # el serpador de columnas
    index=False # al exportar escribe el indice de filas (como informacion)
    )

# %% [markdown]
# ## SQL

# %%
# revisar como se escribe una rutina de conexión a una base de datos
try:
  import pyodbc # libreria para realizar conexión
  conn = pyodbc.connect(
                      'Driver={SQL Server};' # driver de conexión
                      'Server= SERVERlesson;' # el servidor / donde está?
                      'Database= DBlesson;' # nombre de la base de datos
                      'user = feruro;' # usuario con permisos de conexion
                      'password = seguro123456' # password /credenciales
                      'Trusted_Connection= yes;' # que utilice las credenciales del usuario del equipo
                      ) # credenciales y configuración de la conexion
  cursor = conn.cursor()
except:
  print("No se puede realizar conexión")
# Out:
# No se puede realizar conexión

# %%
try:
  SQL_Query = pd.read_sql_query(
    '''select * FROM dbo.table_lesson''', # query SQL
    conn # cursor conector
    )
except:
  print("Como no se puede realizar conexión no permite realizar el query")
# Out:
# Como no se puede realizar conexión no permite realizar el query

# %% [markdown]
# ## Bibliografía

# %% [markdown]
# * BeginnersGuide. link :https://wiki.python.org/moin/BeginnersGuide/Programmers
# * Uniwebsidad. link :https://uniwebsidad.com/libros/algoritmos-python
